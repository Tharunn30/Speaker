# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/pyannote-database
# Out:
# /content/drive/MyDrive/pyannote-database

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/pyannote-database'

# %%
# !python setup.py install

# %%
# !pip install pyannote.core

# %%
# !pip install pyannote.database==5.0.1
# Out:
# Requirement already satisfied: pyannote.database==5.0.1 in /usr/local/lib/python3.10/dist-packages/pyannote.database-5.0.1+1.gbac3225.dirty-py3.10.egg (5.0.1+1.gbac3225.dirty)
# Requirement already satisfied: pyannote.core>=4.1 in /usr/local/lib/python3.10/dist-packages/pyannote.core-5.0.0-py3.10.egg (from pyannote.database==5.0.1) (5.0.0)
# Requirement already satisfied: pyYAML>=3.12 in /usr/local/lib/python3.10/dist-packages (from pyannote.database==5.0.1) (6.0)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pyannote.database==5.0.1) (1.5.3)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.database==5.0.1) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database==5.0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database==5.0.1) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pyannote.database==5.0.1) (1.22.4)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=4.1->pyannote.database==5.0.1) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=4.1->pyannote.database==5.0.1) (1.10.1)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from pyannote.core>=4.1->pyannote.database==5.0.1) (4.7.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.2.1->pyannote.database==5.0.1) (8.1.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages/colorama-0.4.6-py3.10.egg (from typer[all]>=0.2.1->pyannote.database==5.0.1) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages/shellingham-1.5.1-py3.10.egg (from typer[all]>=0.2.1->pyannote.database==5.0.1) (1.5.1)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.2.1->pyannote.database==5.0.1) (13.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.19->pyannote.database==5.0.1) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database==5.0.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database==5.0.1) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]>=0.2.1->pyannote.database==5.0.1) (0.1.2)

# %%
from pyannote.database import registry
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-de6f8b71bef4> in <cell line: 1>()
# ----> 1 from pyannote.database import registry
#
# /content/drive/MyDrive/pyannote-database/pyannote/database/__init__.py in <module>
#      34 import warnings
#      35
# ---> 36 from .registry import registry, LoadingMode
#      37
#      38 from .database import Database
#
# /content/drive/MyDrive/pyannote-database/pyannote/database/registry.py in <module>
#      36
#      37 from pyannote.database.protocol.protocol import Preprocessors, Protocol
# ---> 38 from .custom import create_protocol, get_init
#      39 from .database import Database
#      40 import yaml
#
# /content/drive/MyDrive/pyannote-database/pyannote/database/custom.py in <module>
#      47
#      48
# ---> 49 from . import protocol as protocol_module
#      50
#      51 from pyannote.database.protocol.protocol import ProtocolFile
#
# /content/drive/MyDrive/pyannote-database/pyannote/database/protocol/__init__.py in <module>
#      29 from .protocol import Protocol
#      30 from .collection import CollectionProtocol
# ---> 31 from .segmentation import SegmentationProtocol
#      32 from .speaker_diarization import SpeakerDiarizationProtocol
#      33 from .speaker_spotting import SpeakerSpottingProtocol
#
# /content/drive/MyDrive/pyannote-database/pyannote/database/protocol/segmentation.py in <module>
#      34 from .protocol import Preprocessor
#      35 from .protocol import Preprocessors
# ---> 36 from pyannote.core import Annotation
#      37 from pyannote.core import Timeline
#      38 from pyannote.core import Segment
#
# ModuleNotFoundError: No module named 'pyannote.core'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
