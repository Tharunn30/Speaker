# %%
# !pip install pyannote.database===5.0.1

# %%
# %cd /content/drive/MyDrive/AMI-diarization-setup
# Out:
# /content/drive/MyDrive/AMI-diarization-setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pyannote.database import registry
registry.load_database("/content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml")
# Out:
# 'AMI-SDM.SpeakerDiarization.only_words' found in /content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI-SDM.SpeakerDiarization.mini' found in /content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.only_words' found in /content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.mini' found in /content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'AMI.SpeakerDiarization.word_and_vocalsounds' found in /content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.

# %%
# tell pyannote.database where to find partition, reference, and wav files
import os
os.environ["PYANNOTE_DATABASE_CONFIG"] = '/content/drive/MyDrive/AMI-diarization-setup/pyannote/database.yml'

# used to automatically find paths to wav files
from pyannote.database import FileFinder
preprocessors = {'audio': FileFinder()}


# initialize 'only_words' experimental protocol
from pyannote.database import get_protocol
only_words = get_protocol('AMI.SpeakerDiarization.only_words', preprocessors=preprocessors)

# %%
# iterate over the training set
for file in only_words.train():
    meeting = file['uri']
    reference = file['annotation']
    path = file['audio']

# iterate over the development set
for file in only_words.development():
    pass

# iterate over the test set
for file in only_words.test():
    pass

# initialize 'word_and_vocalsounds' experimental protocol
word_and_vocalsounds = get_protocol('AMI.SpeakerDiarization.word_and_vocalsounds')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f6d793311943> in <cell line: 2>()
#       1 # iterate over the training set
# ----> 2 for file in only_words.train():
#       3     meeting = file['uri']
#       4     reference = file['annotation']
#       5     path = file['audio']
#
# /usr/local/lib/python3.10/dist-packages/pyannote/database/protocol/protocol.py in subset_helper(self, subset)
#     372                 raise NotImplementedError(msg)
#     373
# --> 374         for file in files:
#     375             yield self.preprocess(file)
#     376
#
# /usr/local/lib/python3.10/dist-packages/pyannote/database/custom.py in subset_iter(self, database, task, protocol, subset, entries, database_yml, **metadata)
#     319     uris = load_lst(resolve_path(Path(uri), database_yml))
#     320
# --> 321     lazy_loader = gather_loaders(entries=entries, database_yml=database_yml)
#     322
#     323     for uri in uris:
#
# /usr/local/lib/python3.10/dist-packages/pyannote/database/custom.py in gather_loaders(entries, database_yml)
#     240                 value = value[1:]
#     241
# --> 242             lazy_loader[key] = Template(value, database_yml)
#     243
#     244         else:
#
# /usr/local/lib/python3.10/dist-packages/pyannote/database/custom.py in Template(template, database_yml)
#      99     if path.suffix not in LOADERS:
#     100         msg = f"No loader for files with '{path.suffix}' suffix"
# --> 101         raise ValueError(msg)
#     102
#     103     Loader = LOADERS[path.suffix].load()
#
# ValueError: No loader for files with '.rttm' suffix
