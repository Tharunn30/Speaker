# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install git+https://github.com/ssmilin/pyannote-audio.git@develop
# Out:
# ...
#   Cloning https://github.com/ssmilin/pyannote-audio.git (to revision develop) to /tmp/pip-req-build-hrkt86k2
#   Running command git clone --filter=blob:none --quiet https://github.com/ssmilin/pyannote-audio.git /tmp/pip-req-build-hrkt86k2
#   Resolved https://github.com/ssmilin/pyannote-audio.git to commit 04aaaf68eb0dbb252d3d05d92b723e0520e8fe8d
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 781.9 kB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote

# %%
# !PYANNOTE_DATABASE_CONFIG="/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml" pyannote-database info SRM.SpeakerDiarization.mini
# Out:
# 2023-09-01 06:07:44.560329: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-01 06:07:46.294675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# ...

# %%
import os
os.environ["PYANNOTE_DATABASE_CONFIG"] = "/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml"
from pyannote.database import get_protocol, FileFinder
dataset = get_protocol("SRM.SpeakerDiarization.mini", {"audio": FileFinder()})
# Out:
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# /usr/local/lib/python3.10/dist-packages/pyannote/database/registry.py:487: UserWarning: Replacing existing SRM.SpeakerDiarization.mini protocol by the one defined in '/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/database.yml'.
#   warnings.warn(f"Replacing existing {realname} protocol by the one defined in '{database_yml}'.")
# ...

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyannote.database import registry
from pyannote.audio.pipelines import SpeakerDiarization as SpeakerDiarizationPipeline
from pyannote.metrics.diarization import DiarizationErrorRate
from pyannote.audio import Inference
from pyannote.database import get_protocol, FileFinder
from pyannote.pipeline import Optimizer
from pyannote.database import registry
registry.load_database("pyannote/database.yml")
ami = registry.get_protocol('SRM.SpeakerDiarization.mini')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-f91399b259ce> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 from pyannote.database import registry
# ----> 5 from pyannote.audio.pipelines import SpeakerDiarization as SpeakerDiarizationPipeline
#       6 from pyannote.metrics.diarization import DiarizationErrorRate
#       7 from pyannote.audio import Inference
#
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/__init__.py in <module>
#      27
#      28
# ---> 29 from .core.inference import Inference
#      30 from .core.io import Audio
#      31 from .core.model import Model
#
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/inference.py in <module>
#      30 from einops import rearrange
#      31 from pyannote.core import Segment, SlidingWindow, SlidingWindowFeature
# ...
