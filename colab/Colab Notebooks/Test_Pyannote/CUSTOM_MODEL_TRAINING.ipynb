# %%
pip install -qq https://github.com/pyannote/pyannote-audio/archive/refs/heads/develop.zip
# Out:
#      - 16.6 MB 5.3 MB/s 0:00:04
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.8/553.8 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 3.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pyannote
print(pyannote.__file__)
# Out:
# None

# %%
# 1. visit hf.co/pyannote/speaker-diarization and accept user conditions
# 2. visit hf.co/pyannote/segmentation and accept user conditions
# 3. visit hf.co/settings/tokens to create an access token
# 4. instantiate pretrained speaker diarization pipeline
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization@2.1",
                                    use_auth_token="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")


# apply the pipeline to an audio file
diarization = pipeline("/content/drive/MyDrive/Colab Notebooks/Test_Pyannote/multispeaker.wav")

# dump the diarization output to disk using RTTM format
with open("audio.rttm", "w") as rttm:
    diarization.write_rttm(rttm)
# Out:
# ...
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.6. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu118. Bad things might happen unless you revert torch to 1.x.
# ...

# %%
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
# Out:
# start=0.6s stop=13.9s speaker_SPEAKER_00
# start=14.6s stop=15.4s speaker_SPEAKER_00
# start=16.1s stop=17.0s speaker_SPEAKER_00
# start=17.0s stop=17.2s speaker_SPEAKER_01
# start=18.1s stop=23.9s speaker_SPEAKER_01
# start=24.0s stop=37.5s speaker_SPEAKER_02

# %%
print(diarization)
# Out:
# [ 00:00:00.554 -->  00:00:13.882] A SPEAKER_00
# [ 00:00:14.564 -->  00:00:15.435] B SPEAKER_00
# [ 00:00:16.134 -->  00:00:17.005] C SPEAKER_00
# [ 00:00:17.005 -->  00:00:17.244] D SPEAKER_01
# [ 00:00:18.080 -->  00:00:23.865] E SPEAKER_01
# [ 00:00:24.018 -->  00:00:37.500] F SPEAKER_02

# %%
print(pipeline)

# %%
print(pipeline.embedding)
# Out:
# speechbrain/spkrec-ecapa-voxceleb

# %%
pipeline.embedding = 'speechbrain/spkrec-xvect-voxceleb'

# %%
print(pipeline.embedding)
# Out:
# speechbrain/spkrec-xvect-voxceleb

# %%
mymodel = Model.from_pretrained('/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/lightning_logs/version_33/checkpoints/epoch=0-step=1.ckpt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-af8181b919e7> in <cell line: 1>()
# ----> 1 mymodel = Model.from_pretrained('/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/lightning_logs/version_33/checkpoints/epoch=0-step=1.ckpt')
#
# NameError: name 'Model' is not defined

# %%
# apply the pipeline to an audio file
diarization = pipeline("/content/drive/MyDrive/Colab Notebooks/Test_Pyannote/multispeaker.wav")

# dump the diarization output to disk using RTTM format
with open("x_vector.rttm", "w") as rttm:
    diarization.write_rttm(rttm)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-55c0be6aa8da> in <cell line: 2>()
#       1 # apply the pipeline to an audio file
# ----> 2 diarization = pipeline("/content/drive/MyDrive/Colab Notebooks/Test_Pyannote/multispeaker.wav")
#       3
#       4 # dump the diarization output to disk using RTTM format
#       5 with open("x_vector.rttm", "w") as rttm:
#
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/pipeline.py in __call__(self, file, **kwargs)
#     323             file = ProtocolFile(file, lazy=self.preprocessors)
#     324
# --> 325         return self.apply(file, **kwargs)
#     326
#     327     def to(self, device: torch.device):
#
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/pipelines/speaker_diarization.py in apply(self, file, num_speakers, min_speakers, max_speakers, return_embeddings, hook)
#     472         )
# ...

# %%
pipeline.embedding
# Out:
# 'speechbrain/spkrec-xvect-voxceleb'

# %%
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
# Out:
# start=0.6s stop=13.9s speaker_SPEAKER_00
# start=14.6s stop=15.4s speaker_SPEAKER_00
# start=16.1s stop=17.0s speaker_SPEAKER_00
# start=17.0s stop=17.2s speaker_SPEAKER_01
# start=18.1s stop=23.9s speaker_SPEAKER_01
# start=24.0s stop=37.5s speaker_SPEAKER_02

# %%
print(diarization)
# Out:
# [ 00:00:00.554 -->  00:00:13.882] A SPEAKER_00
# [ 00:00:14.564 -->  00:00:15.435] B SPEAKER_00
# [ 00:00:16.134 -->  00:00:17.005] C SPEAKER_00
# [ 00:00:17.005 -->  00:00:17.244] D SPEAKER_01
# [ 00:00:18.080 -->  00:00:23.865] E SPEAKER_01
# [ 00:00:24.018 -->  00:00:37.500] F SPEAKER_02

# %%
from pyannote.audio import Model
mymodel = Model.from_pretrained('https://huggingface.co/speechbrain/spkrec-xvect-voxceleb/blob/main/embedding_model.ckpt')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-28-d7014d9d819a> in <cell line: 2>()
#       1 from pyannote.audio import Model
# ----> 2 mymodel = Model.from_pretrained('https://huggingface.co/speechbrain/spkrec-xvect-voxceleb/blob/main/embedding_model.ckpt')
#
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/model.py in from_pretrained(cls, checkpoint, map_location, hparams_file, strict, use_auth_token, cache_dir, **kwargs)
#     686
#     687         # obtain model class from the checkpoint
# --> 688         loaded_checkpoint = pl_load(path_for_pl, map_location=map_location)
#     689         module_name: str = loaded_checkpoint["pyannote.audio"]["architecture"]["module"]
#     690         module = import_module(module_name)
#
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/utilities/cloud_io.py in _load(path_or_url, map_location)
# ...

# %%
pipeline = SpeakerDiarizationPipeline(segmentation=mymodel)

# %%
from pyannote.audio import Model
mymodel = Model.from_pretrained('speechbrain/spkrec-resnet-voxceleb')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/speechbrain/spkrec-resnet-voxceleb/resolve/main/pytorch_model.bin
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-30-fa2e308a0e83> in <cell line: 2>()
#       1 from pyannote.audio import Model
# ...

# %%
mymodel = Model.from_pretrained('speechbrain/spkrec-ecapa-voxceleb')

# %%
from pyannote.audio import Model
mymodel2 = Model.from_pretrained('speechbrain/spkrec-resnet-voxceleb')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     260     try:
# --> 261         response.raise_for_status()
#     262     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/speechbrain/spkrec-resnet-voxceleb/resolve/main/pytorch_model.bin
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-25-d3463411c61a> in <cell line: 2>()
#       1 from pyannote.audio import Model
# ...

# %%
from pyannote.audio import Pipeline
pipeline2 = Pipeline.from_pretrained("pyannote/speaker-diarization@2.1",
                                    use_auth_token="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")
# Out:
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.0.6. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../root/.cache/torch/pyannote/models--pyannote--segmentation/snapshots/c4c8ceafcbb3a7a280c2d357aee9fbc9b0be7f9b/pytorch_model.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 2.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.0.1+cu118. Bad things might happen unless you revert torch to 1.x.

# %%
pipeline2.embedding = 'speechbrain/spkrec-resnet-voxceleb'

# %%
pipeline2.embedding
# Out:
# 'speechbrain/spkrec-resnet-voxceleb'

# %%
diarization = pipeline("/content/drive/MyDrive/Colab Notebooks/Test_Pyannote/multispeaker.wav")

# dump the diarization output to disk using RTTM format
with open("resnet.rttm", "w") as rttm:
    diarization.write_rttm(rttm)

# %%
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"start={turn.start:.1f}s stop={turn.end:.1f}s speaker_{speaker}")
