# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop

# %%
# !pip install git+https://github.com/pyannote/pyannote-audio.git@develop
# Out:
# ...
#   Cloning https://github.com/pyannote/pyannote-audio.git (to revision develop) to /tmp/pip-req-build-09l_4nta
#   Running command git clone --filter=blob:none --quiet https://github.com/pyannote/pyannote-audio.git /tmp/pip-req-build-09l_4nta
#   Resolved https://github.com/pyannote/pyannote-audio.git to commit 719492991bea3de31c788e9db2913a786006c7b2
#   Running command git submodule update --init --recursive -q
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python setup.py install
# Out:
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory

# %%
# %cd SRM-diarization-setup-main/
# Out:
# /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main

# %%
import pyannote.audio
pyannote.audio.__version__
# Out:
# '2.1.1'

# %%
from pyannote.audio.tasks import SpeakerDiarization

# %%
# !python train_test_full.py
# Out:
# 2023-08-02 09:41:53.110621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 'SRM.SpeakerDiarization.mini' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/full_database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# 'SRM.SpeakerDiarization.complete' found in /content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/pyannote/full_database.yml does not define the 'scope' of speaker labels (file, database, or global). Setting it to 'file'.
# Protocol SRM.SpeakerDiarization.complete does not provide the path to audio files: adding an 'audio' preprocessor for you. See pyannote.database documentation on how to do that yourself.
# ...

# %%
# !python run_from_model_ver31.py
# Out:
# 2023-08-02 09:47:33.512927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from pyannote.database.util import load_rttm
_, diarization_output = load_rttm('audio-test.rttm').popitem()

# visualize diarization output
diarization_output

# %%
# !python run_from_model_ver31.py
# Out:
# 2023-08-02 09:51:00.007788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
_, ground_truth = load_rttm('/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/rttms/train/conversation1002.rttm').popitem()

ground_truth

# %%
import pytorch_lightning as pl
pl.__version__
# Out:
# '2.0.6'

# %%
import torch
checkpoint=torch.load("/content/drive/MyDrive/Colab Notebooks/pyannote-database-develop/SRM-diarization-setup-main/lightning_logs/version_31/checkpoints/epoch=0-step=1.ckpt")

# %%
import torchvision
print(torchvision.__version__)
# Out:
# 0.15.2+cu118

# %%
import pyannote.audio
pyannote.audio.__version__
# Out:
# '2.1.1'

# %%
import huggingface_hub
huggingface_hub.__version__
# Out:
# '0.16.4'
